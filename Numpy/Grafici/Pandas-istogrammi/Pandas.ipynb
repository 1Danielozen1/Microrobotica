# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### PANDAS

# %%
data = pd.read_csv("./Fuel_Consumption_2000-2022.csv")
data #dataframe
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  VOLVO  XC40 T5 AWD     SUV: SMALL          2.0          4
# 22552  2022  VOLVO  XC60 B5 AWD     SUV: SMALL          2.0          4
# 22553  2022  VOLVO  XC60 B6 AWD     SUV: SMALL          2.0          4
# 22554  2022  VOLVO  XC90 T5 AWD  SUV: STANDARD          2.0          4
# 22555  2022  VOLVO  XC90 T6 AWD  SUV: STANDARD          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  COMB (L/100 KM)  \
# ...

# %%
make = data["MAKE"].values
fuel_consumption = data["FUEL CONSUMPTION"].values

# %%
fuel_consumption
# Out:
# array([ 9.2,  8.5, 12.2, ..., 11. , 11.5, 12.4])

# %% [markdown]
# ### ISTOGRAMMI

# %%
fig, ax = plt.subplots(figsize = (6,3))

#ISTOGRAMMA DELLE FREQUENZE ASSOLUTE
ax.hist(fuel_consumption, bins = 50)
ax.set_xlabel("Consumi l/100Km")
ax.set_ylabel("N° di auto")
plt.show()

# %%
dado = np.random.randint(1,7,10000)

fig, ax = plt.subplots(figsize = (6,3))

ax.hist(dado, bins = 20)
ax.set_xlabel("Punteggio del dado")
ax.set_ylabel("Frequenza assoluta")
plt.show()

# %%
due_dadi = np.random.randint(1,7,10000) + np.random.randint(1,7,10000)

fig, ax = plt.subplots(figsize = (6,3))

ax.hist(due_dadi, bins = 11)
ax.set_xlabel("Punteggio del dado")
ax.set_ylabel("Frequenza assoluta")
plt.show()

# %% [markdown]
# ### GRAFICI DI MATRICI

# %%
matrice = np.random.uniform(0,1,(30,30))
matrice[0] = 0
matrice[-1] = 1
fig, ax = plt.subplots(figsize = (4,4))
ax.imshow(matrice, cmap= "Greens")
plt.show()

# %%
image = plt.imread("./Zucca_particolare.PNG")
image.shape
# Out:
# (603, 597, 4)

# %%
red_component = image[:, :, 0]
green_component = image[:, :, 1]
blue_component = image[:, :, 2]
transparent_component = image[:, :, :3]

# %%
fig, ax = plt.subplots(figsize = (6,6))
ax.imshow(red_component, cmap="Reds_r")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6,3))

ax.hist(red_component.flatten(), bins = 50)
ax.set_xlabel("intensità del rosso")
ax.set_ylabel("Frequenza assoluta")
plt.show()

# %% [markdown]
# ## SOTTOGRAFICI

# %%
fig, axs = plt.subplots(nrows=4, ncols=2, figsize = (16,16))

axs[0,0].imshow(red_component, cmap = "Reds_r")
axs[0,1].hist(red_component.flatten(), bins = 50)
axs[0,0].set_title("Componente rossa")
axs[0,1].set_title("Intensità colore")

axs[1,0].imshow(green_component, cmap = "Greens_r")
axs[1,1].hist(green_component.flatten(), bins = 50)
axs[1,0].set_title("Componente verde")
axs[1,1].set_title("Intensità colore")

axs[2,0].imshow(blue_component, cmap = "Blues_r")
axs[2,1].hist(blue_component.flatten(), bins = 50)
axs[2,0].set_title("Componente blu")
axs[2,1].set_title("Intensità colore")

axs[3,0].imshow(transparent_component, cmap = "Greys_r")
axs[3,1].hist(transparent_component.flatten(), bins = 50)
axs[3,0].set_title("Componente trasparente")
axs[3,1].set_title("Intensità colore")
plt.show()
